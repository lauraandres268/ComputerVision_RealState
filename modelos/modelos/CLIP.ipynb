# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta Ángel

df = pd.read_csv('/content/drive/MyDrive/CEU SAN PABLO/TFM/datos_imagenes.csv')

image_folder_path = '/content/drive/MyDrive/CEU SAN PABLO/TFM/fotos'

# %%
# Ruta Álvaro

df = pd.read_csv('/content/drive/MyDrive/tfm/TFM/datos_imagenes.csv')

image_folder_path = '/content/drive/MyDrive/tfg/TFM/fotos'

# %%
df.head()
# Out:
#                                    address  \
# 0                         Calle de Zurbano
# 1                         Calle de Zurbano
# 2                 Calle de Hilarión Eslava
# 3              Calle de Francisco de Rojas
# 4  Paseo Walkway de San Francisco de Sales
#
#                                          agency_name  bathroom_count  \
# 0                                         Ambassador               4
# 1                                 Walter Haus Madrid               4
# 2                                 Walter Haus Madrid               5
# 3                                 Walter Haus Madrid               3
# 4  DIZA Consultores Inmobiliaria - Propiedades de...               3
#
#    bedroom_count  floor   latitude  longitude  lot_size  \
# 0              5    5.0  40.435694  -3.691642       344
# 1              6    5.0  40.433373  -3.693010       355
# 2              5    2.0  40.435637  -3.716426       265
# 3              3    3.0  40.430204  -3.698828       227
# 4              2    9.0  40.440927  -3.717716       133
#
#                                 property_description  \
# 0  Fantástico tríplex muy luminoso y bien ubicado...
# 1  Este exclusivo inmueble, ubicado en el prestig...
# 2  Presentamos una espectacular vivienda de lujo,...
# 3  Vivienda totalmente reformada y amueblada que ...
# 4  DIZA Consultores presenta atico triplex en el ...
#
#                                      property_images  ...  neighborhood  \
# 0  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...      Chamberí
# 1  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...      Chamberí
# 2  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...      Chamberí
# 3  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...      Chamberí
# 4  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...      Chamberí
#
#   exterior ascensor  dist_metro_m  property_type_flat  \
# 0      1.0      1.0    339.756321                True
# 1      1.0      1.0    372.735657                True
# 2      1.0      1.0    325.628226                True
# 3      1.0      1.0    371.309203                True
# 4      1.0      1.0    499.021336                True
#
#    energy_certificate_encoded  property_type_chalet  altura_techo  \
# 0                           2                 False         2.695
# 1                           1                 False         2.720
# 2                           4                 False         2.745
# 3                           2                 False         2.705
# 4                           3                 False         2.720
#
#        tipo_suelo     estilo
# 0         parquet   eclectic
# 1         parquet   eclectic
# 2         parquet    coastal
# 3         parquet  craftsman
# 4  sin_predicción    coastal
#
# [5 rows x 22 columns]

# %%
import pandas as pd
from PIL import Image
import torch
import os
from transformers import CLIPProcessor, CLIPModel
from tqdm import tqdm # Para ver el progreso

def extract_clip_embeddings(df, image_folder_path, num_images_per_property=1):
    """
    Extrae embeddings de imágenes utilizando el modelo CLIP y los añade al DataFrame.

    Args:
        df (pd.DataFrame): DataFrame con la información de las propiedades.
        image_folder_path (str): Ruta a la carpeta que contiene las imágenes.
        num_images_per_property (int): Número de imágenes a procesar por propiedad.
                                        Por defecto, se procesa solo la primera imagen.

    Returns:
        pd.DataFrame: El DataFrame original con las nuevas columnas de embeddings.
    """
    # Cargar el modelo CLIP y el procesador una sola vez
    model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
    processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

    # Mover el modelo a la GPU si está disponible
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)

    # Lista para almacenar los embeddings de todas las propiedades
    all_embeddings = []

    print(f"Extrayendo embeddings CLIP para {len(df)} propiedades...")

    # Usamos tqdm para tener una barra de progreso
    for idx in tqdm(df.index, desc="Procesando propiedades"):
        property_embeddings = []
        # Obtener las rutas de las imágenes para esta propiedad
        image_files = sorted([
            f for f in os.listdir(image_folder_path)
            if f.startswith(f'foto_{idx}_') and f.endswith('.webp')
        ])

        if not image_files:
            # Si no hay imágenes, añadir un vector de ceros o NaN del tamaño correcto
            # Para CLIP-ViT-B/32, el tamaño del embedding es 512
            property_embeddings.append(torch.zeros(512).tolist()) # Usamos .tolist() para guardar en DataFrame
            print(f"Advertencia: No hay imágenes para propiedad {idx}. Se añadirá un embedding de ceros.")
        else:
            # Procesar hasta `num_images_per_property` imágenes
            for i, img_file in enumerate(image_files[:num_images_per_property]):
                img_path = os.path.join(image_folder_path, img_file)
                try:
                    image = Image.open(img_path).convert("RGB") # Asegurarse de que sea RGB
                    inputs = processor(images=image, return_tensors="pt").to(device)
                    with torch.no_grad():
                        image_features = model.get_image_features(**inputs)
                    # Convertir a numpy array y luego a lista para almacenar en el DataFrame
                    property_embeddings.append(image_features.squeeze().cpu().numpy().tolist())
                except Exception as e:
                    print(f"Error procesando {img_path}: {str(e)}. Se añadirá un embedding de ceros.")
                    property_embeddings.append(torch.zeros(512).tolist()) # Añadir ceros en caso de error

        # Si se procesan varias imágenes por propiedad, podrías promediar los embeddings
        # o concatenarlos, dependiendo de tu estrategia.
        # Por ahora, si num_images_per_property > 1, solo estamos tomando el embedding de la primera.
        # Si num_images_per_property > 1 y quieres combinar, aquí sería el lugar:
        # Por ejemplo, para promediar si hay más de una imagen y quieres un solo embedding por propiedad:
        # if len(property_embeddings) > 1:
        #     all_embeddings.append(torch.tensor(property_embeddings).mean(dim=0).tolist())
        # else:
        all_embeddings.append(property_embeddings[0]) # Solo la primera imagen o el embedding de ceros

    # Crear nuevas columnas para los embeddings
    # Cada elemento del embedding será una columna separada.
    # El tamaño del embedding para CLIP-ViT-B/32 es 512
    embedding_df = pd.DataFrame(all_embeddings, columns=[f'clip_embedding_{i}' for i in range(512)], index=df.index)

    # Concatenar el DataFrame original con los nuevos embeddings
    df_with_embeddings = pd.concat([df, embedding_df], axis=1)

    return df_with_embeddings

# %%
# Asegúrate de que las rutas y el DataFrame estén cargados correctamente
# df = pd.read_csv('/content/drive/MyDrive/CEU SAN PABLO/TFM/datos_imagenes.csv')
# image_folder_path = '/content/drive/MyDrive/CEU SAN PABLO/TFM/fotos'

# Extraer los embeddings de CLIP (usando la primera imagen de cada propiedad por defecto)
df_with_clip_embeddings = extract_clip_embeddings(df, image_folder_path)

# Guardar el DataFrame actualizado con los embeddings
df_with_clip_embeddings.to_csv('datos_con_clip_embeddings.csv', index=False)

print("\nDataFrame con embeddings CLIP guardado en 'datos_con_clip_embeddings.csv'")
print(df_with_clip_embeddings.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Extrayendo embeddings CLIP para 1161 propiedades...
# Procesando propiedades:   0%|          | 0/1161 [00:00<?, ?it/s]
# Procesando propiedades:   0%|          | 1/1161 [00:08<2:44:06,  8.49s/it]
# Procesando propiedades:   0%|          | 2/1161 [00:09<1:13:20,  3.80s/it]
# Procesando propiedades:   0%|          | 3/1161 [00:09<47:32,  2.46s/it]
# Procesando propiedades:   0%|          | 4/1161 [00:11<37:35,  1.95s/it]
# Procesando propiedades:   0%|          | 5/1161 [00:11<29:09,  1.51s/it]
# Procesando propiedades:   1%|          | 6/1161 [00:12<25:53,  1.34s/it]
# Procesando propiedades:   1%|          | 7/1161 [00:13<20:04,  1.04s/it]
# Procesando propiedades:   1%|          | 8/1161 [00:13<16:57,  1.13it/s]
# Procesando propiedades:   1%|          | 9/1161 [00:14<14:08,  1.36it/s]
# Procesando propiedades:   1%|          | 10/1161 [00:14<14:02,  1.37it/s]
# Procesando propiedades:   1%|          | 11/1161 [00:15<14:31,  1.32it/s]
# Procesando propiedades:   1%|          | 12/1161 [00:16<13:21,  1.43it/s]
# Procesando propiedades:   1%|          | 13/1161 [00:16<12:03,  1.59it/s]
# Procesando propiedades:   1%|          | 14/1161 [00:17<11:05,  1.72it/s]
# Procesando propiedades:   1%|▏         | 15/1161 [00:17<11:08,  1.71it/s]
# Procesando propiedades:   1%|▏         | 16/1161 [00:18<10:59,  1.74it/s]
# Procesando propiedades:   1%|▏         | 17/1161 [00:18<10:46,  1.77it/s]
# Procesando propiedades:   2%|▏         | 18/1161 [00:19<10:43,  1.78it/s]
# Procesando propiedades:   2%|▏         | 19/1161 [00:19<10:21,  1.84it/s]
# Procesando propiedades:   2%|▏         | 20/1161 [00:20<10:07,  1.88it/s]
# Procesando propiedades:   2%|▏         | 21/1161 [00:21<10:46,  1.76it/s]
# Procesando propiedades:   2%|▏         | 22/1161 [00:21<10:06,  1.88it/s]
# Procesando propiedades:   2%|▏         | 23/1161 [00:22<10:08,  1.87it/s]
# Procesando propiedades:   2%|▏         | 24/1161 [00:23<12:47,  1.48it/s]
# Procesando propiedades:   2%|▏         | 25/1161 [00:23<12:19,  1.54it/s]
# Procesando propiedades:   2%|▏         | 26/1161 [00:24<12:25,  1.52it/s]
# Procesando propiedades:   2%|▏         | 27/1161 [00:24<11:39,  1.62it/s]
# Procesando propiedades:   2%|▏         | 28/1161 [00:26<14:39,  1.29it/s]
# Procesando propiedades:   2%|▏         | 29/1161 [00:26<12:40,  1.49it/s]
# Procesando propiedades:   3%|▎         | 30/1161 [00:27<12:06,  1.56it/s]
# Procesando propiedades:   3%|▎         | 31/1161 [00:27<11:20,  1.66it/s]
# Procesando propiedades:   3%|▎         | 32/1161 [00:28<10:52,  1.73it/s]
# Procesando propiedades:   3%|▎         | 33/1161 [00:28<10:05,  1.86it/s]
# Procesando propiedades:   3%|▎         | 34/1161 [00:29<09:56,  1.89it/s]
# Procesando propiedades:   3%|▎         | 35/1161 [00:29<10:17,  1.82it/s]
# Procesando propiedades:   3%|▎         | 36/1161 [00:30<10:47,  1.74it/s]
# Procesando propiedades:   3%|▎         | 37/1161 [00:30<10:38,  1.76it/s]
# Procesando propiedades:   3%|▎         | 38/1161 [00:31<10:30,  1.78it/s]
# Procesando propiedades:   3%|▎         | 39/1161 [00:31<10:40,  1.75it/s]
# Procesando propiedades:   3%|▎         | 40/1161 [00:32<10:38,  1.76it/s]
# Procesando propiedades:   4%|▎         | 41/1161 [00:33<10:09,  1.84it/s]
# Procesando propiedades:   4%|▎         | 42/1161 [00:33<09:56,  1.88it/s]
# Procesando propiedades:   4%|▎         | 43/1161 [00:33<09:37,  1.94it/s]
# Procesando propiedades:   4%|▍         | 44/1161 [00:34<09:26,  1.97it/s]
# Procesando propiedades:   4%|▍         | 45/1161 [00:35<09:59,  1.86it/s]
# Procesando propiedades:   4%|▍         | 46/1161 [00:35<11:28,  1.62it/s]
# Procesando propiedades:   4%|▍         | 47/1161 [00:36<10:58,  1.69it/s]
# Procesando propiedades:   4%|▍         | 48/1161 [00:37<11:31,  1.61it/s]
# Procesando propiedades:   4%|▍         | 49/1161 [00:37<11:53,  1.56it/s]
# Procesando propiedades:   4%|▍         | 50/1161 [00:38<12:00,  1.54it/s]
# Procesando propiedades:   4%|▍         | 51/1161 [00:39<12:00,  1.54it/s]
# Procesando propiedades:   4%|▍         | 52/1161 [00:39<10:59,  1.68it/s]
# Procesando propiedades:   5%|▍         | 53/1161 [00:40<11:36,  1.59it/s]
# Procesando propiedades:   5%|▍         | 54/1161 [00:41<13:49,  1.33it/s]
# Procesando propiedades:   5%|▍         | 55/1161 [00:42<14:43,  1.25it/s]
# Procesando propiedades:   5%|▍         | 56/1161 [00:43<16:06,  1.14it/s]
# Procesando propiedades:   5%|▍         | 57/1161 [00:44<15:20,  1.20it/s]
# Procesando propiedades:   5%|▍         | 58/1161 [00:45<16:09,  1.14it/s]
# Procesando propiedades:   5%|▌         | 59/1161 [00:45<16:01,  1.15it/s]
# Procesando propiedades:   5%|▌         | 60/1161 [00:46<15:46,  1.16it/s]
# Procesando propiedades:   5%|▌         | 61/1161 [00:48<19:25,  1.06s/it]
# Procesando propiedades:   5%|▌         | 62/1161 [01:07<1:59:27,  6.52s/it]
# Procesando propiedades:   5%|▌         | 63/1161 [02:10<7:10:52, 23.55s/it]
# Procesando propiedades:   6%|▌         | 64/1161 [02:45<8:13:37, 27.00s/it]
# Procesando propiedades:   6%|▌         | 65/1161 [02:46<5:47:12, 19.01s/it]
# Procesando propiedades:   6%|▌         | 66/1161 [02:46<4:03:44, 13.36s/it]
# Procesando propiedades:   6%|▌         | 67/1161 [02:46<2:51:18,  9.40s/it]
# Procesando propiedades:   6%|▌         | 68/1161 [02:46<2:00:42,  6.63s/it]
# Procesando propiedades:   6%|▌         | 69/1161 [02:46<1:25:25,  4.69s/it]
# Procesando propiedades:   6%|▌         | 70/1161 [02:47<1:00:40,  3.34s/it]
# Procesando propiedades:   6%|▌         | 71/1161 [02:47<45:02,  2.48s/it]
# Procesando propiedades:  50%|████▉     | 576/1161 [06:20<03:05,  3.16it/s]
# Procesando propiedades:  50%|████▉     | 577/1161 [06:20<02:52,  3.38it/s]
# Procesando propiedades:  50%|████▉     | 578/1161 [06:20<02:40,  3.63it/s]
# Procesando propiedades:  50%|████▉     | 579/1161 [06:20<02:37,  3.70it/s]
# Procesando propiedades:  50%|████▉     | 580/1161 [06:21<02:30,  3.86it/s]
# Procesando propiedades:  50%|█████     | 581/1161 [06:21<02:30,  3.85it/s]
# Procesando propiedades:  50%|█████     | 582/1161 [06:21<02:26,  3.95it/s]
# Procesando propiedades:  50%|█████     | 583/1161 [06:21<02:26,  3.94it/s]
# Procesando propiedades:  50%|█████     | 584/1161 [06:22<02:41,  3.58it/s]
# Procesando propiedades:  50%|█████     | 585/1161 [06:22<02:31,  3.81it/s]
# Procesando propiedades:  50%|█████     | 586/1161 [06:22<02:18,  4.14it/s]
# Procesando propiedades:  51%|█████     | 587/1161 [06:22<02:19,  4.10it/s]
# Procesando propiedades:  51%|█████     | 588/1161 [06:23<03:07,  3.05it/s]
# Procesando propiedades:  51%|█████     | 589/1161 [06:23<03:20,  2.85it/s]
# Procesando propiedades:  51%|█████     | 590/1161 [06:23<02:52,  3.31it/s]
# Procesando propiedades:  51%|█████     | 591/1161 [06:24<02:33,  3.72it/s]
# Procesando propiedades:  51%|█████     | 592/1161 [06:24<02:14,  4.22it/s]
# Procesando propiedades:  51%|█████     | 593/1161 [06:24<02:01,  4.69it/s]
# Procesando propiedades:  51%|█████     | 594/1161 [06:24<01:49,  5.17it/s]
# Procesando propiedades:  51%|█████     | 595/1161 [06:24<01:48,  5.23it/s]
# Procesando propiedades:  51%|█████▏    | 596/1161 [06:24<01:39,  5.66it/s]
# Procesando propiedades:  51%|█████▏    | 597/1161 [06:25<01:39,  5.64it/s]
# Procesando propiedades:  52%|█████▏    | 598/1161 [06:25<01:40,  5.61it/s]
# Procesando propiedades:  52%|█████▏    | 599/1161 [06:25<01:33,  5.98it/s]
# Procesando propiedades:  52%|█████▏    | 600/1161 [06:25<01:33,  5.98it/s]
# Procesando propiedades:  52%|█████▏    | 601/1161 [06:25<01:31,  6.09it/s]
# Procesando propiedades:  52%|█████▏    | 602/1161 [06:25<01:28,  6.34it/s]
# Procesando propiedades:  52%|█████▏    | 603/1161 [06:26<01:30,  6.20it/s]
# Procesando propiedades:  52%|█████▏    | 604/1161 [06:26<01:27,  6.34it/s]
# Procesando propiedades:  52%|█████▏    | 605/1161 [06:26<01:26,  6.44it/s]
# Procesando propiedades:  52%|█████▏    | 606/1161 [06:26<01:24,  6.55it/s]
# Procesando propiedades:  52%|█████▏    | 607/1161 [06:27<04:12,  2.20it/s]
# Procesando propiedades:  52%|█████▏    | 608/1161 [06:27<03:23,  2.72it/s]
# Procesando propiedades:  52%|█████▏    | 609/1161 [06:28<02:55,  3.14it/s]
# Procesando propiedades:  53%|█████▎    | 610/1161 [06:28<02:28,  3.72it/s]
# Procesando propiedades:  53%|█████▎    | 611/1161 [06:28<02:21,  3.89it/s]
# Procesando propiedades:  53%|█████▎    | 612/1161 [06:29<03:21,  2.73it/s]
# Procesando propiedades:  53%|█████▎    | 613/1161 [06:29<02:48,  3.25it/s]
# Procesando propiedades:  53%|█████▎    | 614/1161 [06:29<02:23,  3.80it/s]
# Procesando propiedades:  53%|█████▎    | 615/1161 [06:29<02:05,  4.36it/s]
# Procesando propiedades:  53%|█████▎    | 616/1161 [06:29<02:02,  4.46it/s]
# Procesando propiedades:  53%|█████▎    | 617/1161 [06:29<01:55,  4.73it/s]
# Procesando propiedades:  53%|█████▎    | 618/1161 [06:30<01:52,  4.83it/s]
# Procesando propiedades:  53%|█████▎    | 619/1161 [06:30<01:44,  5.17it/s]
# Procesando propiedades:  53%|█████▎    | 620/1161 [06:30<01:39,  5.43it/s]
# Procesando propiedades:  53%|█████▎    | 621/1161 [06:30<01:42,  5.28it/s]
# ...
# Procesando propiedades:  86%|████████▌ | 993/1161 [08:44<00:38,  4.36it/s]
# Procesando propiedades:  86%|████████▌ | 994/1161 [08:44<00:41,  4.04it/s]
# Procesando propiedades:  86%|████████▌ | 995/1161 [08:45<00:42,  3.95it/s]
# Procesando propiedades:  86%|████████▌ | 996/1161 [08:45<00:42,  3.86it/s]
# Procesando propiedades:  86%|████████▌ | 997/1161 [08:45<00:40,  4.03it/s]
# Procesando propiedades:  86%|████████▌ | 998/1161 [08:45<00:43,  3.73it/s]
# Procesando propiedades:  86%|████████▌ | 999/1161 [08:46<00:41,  3.90it/s]
# Procesando propiedades:  86%|████████▌ | 1000/1161 [08:46<00:53,  3.03it/s]
# Procesando propiedades:  86%|████████▌ | 1001/1161 [08:46<00:56,  2.85it/s]
# Procesando propiedades:  86%|████████▋ | 1002/1161 [08:47<00:53,  2.95it/s]
# Procesando propiedades:  86%|████████▋ | 1003/1161 [08:47<00:48,  3.23it/s]
# Procesando propiedades:  86%|████████▋ | 1004/1161 [08:47<00:41,  3.82it/s]
# Procesando propiedades:  87%|████████▋ | 1005/1161 [08:47<00:35,  4.35it/s]
# Procesando propiedades:  87%|████████▋ | 1006/1161 [08:47<00:32,  4.76it/s]
# Procesando propiedades:  87%|████████▋ | 1007/1161 [08:48<00:31,  4.89it/s]
# Procesando propiedades:  87%|████████▋ | 1008/1161 [08:48<00:29,  5.17it/s]
# Procesando propiedades:  87%|████████▋ | 1009/1161 [08:48<00:27,  5.46it/s]
# Procesando propiedades:  87%|████████▋ | 1010/1161 [08:48<00:27,  5.54it/s]
# Procesando propiedades:  87%|████████▋ | 1011/1161 [08:48<00:26,  5.61it/s]
# Procesando propiedades:  87%|████████▋ | 1012/1161 [08:49<00:25,  5.93it/s]
# Procesando propiedades:  87%|████████▋ | 1013/1161 [08:50<01:03,  2.32it/s]
# Procesando propiedades:  87%|████████▋ | 1014/1161 [08:50<00:51,  2.85it/s]
# Procesando propiedades:  87%|████████▋ | 1015/1161 [08:50<00:42,  3.45it/s]
# Procesando propiedades:  88%|████████▊ | 1016/1161 [08:50<00:37,  3.86it/s]
# Procesando propiedades:  88%|████████▊ | 1017/1161 [08:50<00:33,  4.33it/s]
# Procesando propiedades:  88%|████████▊ | 1018/1161 [08:50<00:29,  4.81it/s]
# Procesando propiedades:  88%|████████▊ | 1019/1161 [08:51<00:27,  5.21it/s]
# Procesando propiedades:  88%|████████▊ | 1020/1161 [08:51<00:25,  5.58it/s]
# Procesando propiedades:  88%|████████▊ | 1021/1161 [08:51<00:23,  5.88it/s]
# Procesando propiedades:  88%|████████▊ | 1022/1161 [08:51<00:23,  6.02it/s]
# Procesando propiedades:  88%|████████▊ | 1023/1161 [08:51<00:24,  5.58it/s]
# Procesando propiedades:  88%|████████▊ | 1024/1161 [08:52<01:00,  2.26it/s]
# Procesando propiedades:  88%|████████▊ | 1025/1161 [08:52<00:48,  2.78it/s]
# Procesando propiedades:  88%|████████▊ | 1026/1161 [08:53<00:42,  3.20it/s]
# Procesando propiedades:  88%|████████▊ | 1027/1161 [08:53<00:35,  3.76it/s]
# Procesando propiedades:  89%|████████▊ | 1028/1161 [08:53<00:30,  4.34it/s]
# Procesando propiedades:  89%|████████▊ | 1029/1161 [08:53<00:31,  4.23it/s]
# Procesando propiedades:  89%|████████▊ | 1030/1161 [08:53<00:28,  4.61it/s]
# Procesando propiedades:  89%|████████▉ | 1031/1161 [08:54<00:25,  5.02it/s]
# Procesando propiedades:  89%|████████▉ | 1032/1161 [08:54<00:23,  5.46it/s]
# Procesando propiedades:  89%|████████▉ | 1033/1161 [08:54<00:22,  5.70it/s]
# Procesando propiedades:  89%|████████▉ | 1034/1161 [08:54<00:21,  5.96it/s]
# Procesando propiedades:  89%|████████▉ | 1035/1161 [08:54<00:20,  6.18it/s]
# Procesando propiedades:  89%|████████▉ | 1036/1161 [08:55<00:41,  2.99it/s]
# Procesando propiedades:  89%|████████▉ | 1037/1161 [08:55<00:34,  3.57it/s]
# Procesando propiedades:  89%|████████▉ | 1038/1161 [08:55<00:30,  4.09it/s]
# Procesando propiedades:  89%|████████▉ | 1039/1161 [08:55<00:27,  4.51it/s]
# Procesando propiedades:  90%|████████▉ | 1040/1161 [08:55<00:24,  4.97it/s]
# Procesando propiedades:  90%|████████▉ | 1041/1161 [08:56<00:23,  5.18it/s]
# Procesando propiedades:  90%|████████▉ | 1042/1161 [08:56<00:21,  5.55it/s]
# Procesando propiedades:  90%|████████▉ | 1043/1161 [08:56<00:20,  5.90it/s]
# Procesando propiedades:  90%|████████▉ | 1044/1161 [08:56<00:19,  6.10it/s]
# Procesando propiedades:  90%|█████████ | 1045/1161 [08:56<00:18,  6.20it/s]
# Procesando propiedades:  90%|█████████ | 1046/1161 [08:56<00:18,  6.11it/s]
# Procesando propiedades:  90%|█████████ | 1047/1161 [08:57<00:18,  6.19it/s]
# Procesando propiedades:  90%|█████████ | 1048/1161 [08:57<00:17,  6.30it/s]
# Procesando propiedades:  90%|█████████ | 1049/1161 [08:57<00:18,  6.18it/s]
# Procesando propiedades:  90%|█████████ | 1050/1161 [08:57<00:18,  6.06it/s]
# Procesando propiedades:  91%|█████████ | 1051/1161 [08:57<00:21,  5.12it/s]
# Procesando propiedades:  91%|█████████ | 1052/1161 [08:58<00:23,  4.72it/s]
# Procesando propiedades:  91%|█████████ | 1053/1161 [08:58<00:24,  4.41it/s]
# Procesando propiedades:  91%|█████████ | 1054/1161 [08:58<00:33,  3.16it/s]
# Procesando propiedades:  91%|█████████ | 1055/1161 [08:59<00:55,  1.92it/s]
# Procesando propiedades:  91%|█████████ | 1056/1161 [09:00<00:46,  2.24it/s]
# Procesando propiedades:  91%|█████████ | 1057/1161 [09:00<00:39,  2.64it/s]
# Procesando propiedades:  91%|█████████ | 1058/1161 [09:00<00:34,  3.00it/s]
# Procesando propiedades:  91%|█████████ | 1059/1161 [09:00<00:32,  3.11it/s]
# Procesando propiedades:  91%|█████████▏| 1060/1161 [09:01<00:27,  3.71it/s]
# Procesando propiedades:  91%|█████████▏| 1061/1161 [09:01<00:23,  4.18it/s]
# Procesando propiedades:  91%|█████████▏| 1062/1161 [09:01<00:21,  4.68it/s]
# Procesando propiedades:  92%|█████████▏| 1063/1161 [09:01<00:20,  4.76it/s]
# Procesando propiedades:  92%|█████████▏| 1064/1161 [09:01<00:19,  4.88it/s]
# Procesando propiedades:  92%|█████████▏| 1065/1161 [09:01<00:18,  5.24it/s]
# Procesando propiedades:  92%|█████████▏| 1066/1161 [09:02<00:17,  5.28it/s]
# Procesando propiedades:  92%|█████████▏| 1067/1161 [09:02<00:17,  5.49it/s]
# Procesando propiedades:  92%|█████████▏| 1068/1161 [09:02<00:15,  5.83it/s]
# Procesando propiedades:  92%|█████████▏| 1069/1161 [09:02<00:15,  6.09it/s]
# Procesando propiedades:  92%|█████████▏| 1070/1161 [09:02<00:14,  6.24it/s]
# Procesando propiedades:  92%|█████████▏| 1071/1161 [09:02<00:14,  6.35it/s]
# Procesando propiedades:  92%|█████████▏| 1072/1161 [09:02<00:13,  6.57it/s]
# Procesando propiedades:  92%|█████████▏| 1073/1161 [09:03<00:13,  6.54it/s]
# Procesando propiedades:  93%|█████████▎| 1074/1161 [09:04<00:38,  2.24it/s]
# Procesando propiedades:  93%|█████████▎| 1075/1161 [09:04<00:30,  2.80it/s]
# Procesando propiedades:  93%|█████████▎| 1076/1161 [09:04<00:25,  3.39it/s]
# Procesando propiedades:  93%|█████████▎| 1077/1161 [09:04<00:21,  3.96it/s]
# Procesando propiedades:  93%|█████████▎| 1078/1161 [09:04<00:18,  4.45it/s]
# Procesando propiedades:  93%|█████████▎| 1079/1161 [09:05<00:21,  3.83it/s]
# Procesando propiedades:  93%|█████████▎| 1080/1161 [09:05<00:19,  4.25it/s]
# Procesando propiedades:  93%|█████████▎| 1081/1161 [09:05<00:16,  4.75it/s]
# Procesando propiedades:  93%|█████████▎| 1082/1161 [09:05<00:15,  5.14it/s]
# Procesando propiedades:  93%|█████████▎| 1083/1161 [09:05<00:14,  5.38it/s]
# Procesando propiedades:  93%|█████████▎| 1084/1161 [09:06<00:14,  5.23it/s]
# Procesando propiedades:  93%|█████████▎| 1085/1161 [09:06<00:13,  5.50it/s]
# Procesando propiedades:  94%|█████████▎| 1086/1161 [09:06<00:13,  5.62it/s]
# Procesando propiedades:  94%|█████████▎| 1087/1161 [09:06<00:13,  5.51it/s]
# Procesando propiedades:  94%|█████████▎| 1088/1161 [09:07<00:33,  2.19it/s]
# Procesando propiedades:  94%|█████████▍| 1089/1161 [09:07<00:26,  2.73it/s]
# Procesando propiedades:  94%|█████████▍| 1090/1161 [09:08<00:22,  3.18it/s]
# Procesando propiedades:  94%|█████████▍| 1091/1161 [09:08<00:18,  3.77it/s]
# Procesando propiedades:  94%|█████████▍| 1092/1161 [09:08<00:16,  4.26it/s]
# Procesando propiedades:  94%|█████████▍| 1093/1161 [09:08<00:14,  4.78it/s]
# Procesando propiedades:  94%|█████████▍| 1094/1161 [09:08<00:12,  5.22it/s]
# Procesando propiedades:  94%|█████████▍| 1095/1161 [09:08<00:12,  5.49it/s]
# Procesando propiedades:  94%|█████████▍| 1096/1161 [09:08<00:11,  5.84it/s]
# Procesando propiedades:  94%|█████████▍| 1097/1161 [09:09<00:10,  6.09it/s]
# Procesando propiedades:  95%|█████████▍| 1098/1161 [09:09<00:10,  6.24it/s]
# Procesando propiedades:  95%|█████████▍| 1099/1161 [09:09<00:09,  6.22it/s]
# Procesando propiedades:  95%|█████████▍| 1100/1161 [09:09<00:09,  6.39it/s]
# Procesando propiedades:  95%|█████████▍| 1101/1161 [09:09<00:10,  5.95it/s]
# Procesando propiedades:  95%|█████████▍| 1102/1161 [09:09<00:09,  6.01it/s]
# Procesando propiedades:  95%|█████████▌| 1103/1161 [09:10<00:10,  5.53it/s]
# Procesando propiedades:  95%|█████████▌| 1104/1161 [09:10<00:10,  5.65it/s]
# Procesando propiedades:  95%|█████████▌| 1105/1161 [09:10<00:10,  5.38it/s]
# Procesando propiedades:  95%|█████████▌| 1106/1161 [09:10<00:09,  5.57it/s]
# Procesando propiedades:  95%|█████████▌| 1107/1161 [09:10<00:09,  5.63it/s]
# Procesando propiedades:  95%|█████████▌| 1108/1161 [09:11<00:11,  4.78it/s]
# Procesando propiedades:  96%|█████████▌| 1109/1161 [09:11<00:11,  4.44it/s]
# Procesando propiedades:  96%|█████████▌| 1110/1161 [09:11<00:11,  4.39it/s]
# Procesando propiedades:  96%|█████████▌| 1111/1161 [09:11<00:11,  4.50it/s]
# Procesando propiedades:  96%|█████████▌| 1112/1161 [09:12<00:10,  4.48it/s]
# Procesando propiedades:  96%|█████████▌| 1113/1161 [09:12<00:10,  4.45it/s]
# Procesando propiedades:  96%|█████████▌| 1114/1161 [09:12<00:10,  4.45it/s]
# Procesando propiedades:  96%|█████████▌| 1115/1161 [09:12<00:11,  4.10it/s]
# Procesando propiedades:  96%|█████████▌| 1116/1161 [09:13<00:10,  4.23it/s]
# Procesando propiedades:  96%|█████████▌| 1117/1161 [09:13<00:10,  4.35it/s]
# Procesando propiedades:  96%|█████████▋| 1118/1161 [09:13<00:10,  4.26it/s]
# Procesando propiedades:  96%|█████████▋| 1119/1161 [09:13<00:10,  3.83it/s]
# Procesando propiedades:  96%|█████████▋| 1120/1161 [09:14<00:10,  4.00it/s]
# Procesando propiedades:  97%|█████████▋| 1121/1161 [09:14<00:09,  4.12it/s]
# Procesando propiedades:  97%|█████████▋| 1122/1161 [09:14<00:08,  4.73it/s]
# Procesando propiedades:  97%|█████████▋| 1123/1161 [09:14<00:07,  5.21it/s]
# Procesando propiedades:  97%|█████████▋| 1124/1161 [09:14<00:07,  5.06it/s]
# Procesando propiedades:  97%|█████████▋| 1125/1161 [09:14<00:06,  5.38it/s]
# Procesando propiedades:  97%|█████████▋| 1126/1161 [09:15<00:06,  5.31it/s]
# Procesando propiedades:  97%|█████████▋| 1127/1161 [09:15<00:06,  5.40it/s]
# Procesando propiedades:  97%|█████████▋| 1128/1161 [09:15<00:05,  5.61it/s]
# Procesando propiedades:  97%|█████████▋| 1129/1161 [09:15<00:05,  5.92it/s]
# Procesando propiedades:  97%|█████████▋| 1130/1161 [09:15<00:05,  5.88it/s]
# Procesando propiedades:  97%|█████████▋| 1131/1161 [09:15<00:04,  6.08it/s]
# Procesando propiedades:  98%|█████████▊| 1132/1161 [09:16<00:04,  5.98it/s]
# Procesando propiedades:  98%|█████████▊| 1133/1161 [09:16<00:04,  6.26it/s]
# Procesando propiedades:  98%|█████████▊| 1134/1161 [09:16<00:04,  6.38it/s]
# Procesando propiedades:  98%|█████████▊| 1135/1161 [09:16<00:04,  6.46it/s]
# Procesando propiedades:  98%|█████████▊| 1136/1161 [09:16<00:04,  5.62it/s]
# Procesando propiedades:  98%|█████████▊| 1137/1161 [09:17<00:04,  5.22it/s]
# Procesando propiedades:  98%|█████████▊| 1138/1161 [09:17<00:04,  5.54it/s]
# Procesando propiedades:  98%|█████████▊| 1139/1161 [09:17<00:03,  5.76it/s]
# Procesando propiedades:  98%|█████████▊| 1140/1161 [09:17<00:03,  5.99it/s]
# Procesando propiedades:  98%|█████████▊| 1141/1161 [09:17<00:03,  6.14it/s]
# Procesando propiedades:  98%|█████████▊| 1142/1161 [09:18<00:08,  2.25it/s]
# Procesando propiedades:  98%|█████████▊| 1143/1161 [09:18<00:06,  2.71it/s]
# Procesando propiedades:  99%|█████████▊| 1144/1161 [09:19<00:07,  2.25it/s]
# Procesando propiedades:  99%|█████████▊| 1145/1161 [09:19<00:05,  2.73it/s]
# Procesando propiedades:  99%|█████████▊| 1146/1161 [09:19<00:04,  3.23it/s]
# Procesando propiedades:  99%|█████████▉| 1147/1161 [09:20<00:03,  3.77it/s]
# Procesando propiedades:  99%|█████████▉| 1148/1161 [09:20<00:03,  4.22it/s]
# Procesando propiedades:  99%|█████████▉| 1149/1161 [09:20<00:02,  4.68it/s]
# Procesando propiedades:  99%|█████████▉| 1150/1161 [09:20<00:02,  5.14it/s]
# Procesando propiedades:  99%|█████████▉| 1151/1161 [09:20<00:01,  5.54it/s]
# Procesando propiedades:  99%|█████████▉| 1152/1161 [09:20<00:01,  5.74it/s]
# Procesando propiedades:  99%|█████████▉| 1153/1161 [09:21<00:03,  2.19it/s]
# Procesando propiedades:  99%|█████████▉| 1154/1161 [09:22<00:02,  2.66it/s]
# Procesando propiedades:  99%|█████████▉| 1155/1161 [09:22<00:01,  3.18it/s]
# Procesando propiedades: 100%|█████████▉| 1156/1161 [09:22<00:01,  3.76it/s]
# Procesando propiedades: 100%|█████████▉| 1157/1161 [09:22<00:00,  4.36it/s]
# Procesando propiedades: 100%|█████████▉| 1158/1161 [09:22<00:00,  4.76it/s]
# Procesando propiedades: 100%|█████████▉| 1159/1161 [09:22<00:00,  5.06it/s]
# Procesando propiedades: 100%|█████████▉| 1160/1161 [09:23<00:00,  5.19it/s]
# Procesando propiedades: 100%|██████████| 1161/1161 [09:23<00:00,  2.06it/s]
# DataFrame con embeddings CLIP guardado en 'datos_con_clip_embeddings.csv'
#                                    address  \
# 0                         Calle de Zurbano
# 1                         Calle de Zurbano
# 2                 Calle de Hilarión Eslava
# 3              Calle de Francisco de Rojas
# 4  Paseo Walkway de San Francisco de Sales
#
#                                          agency_name  bathroom_count  \
# 0                                         Ambassador               4
# 1                                 Walter Haus Madrid               4
# 2                                 Walter Haus Madrid               5
# 3                                 Walter Haus Madrid               3
# 4  DIZA Consultores Inmobiliaria - Propiedades de...               3
#
#    bedroom_count  floor   latitude  longitude  lot_size  \
# 0              5    5.0  40.435694  -3.691642       344
# 1              6    5.0  40.433373  -3.693010       355
# 2              5    2.0  40.435637  -3.716426       265
# 3              3    3.0  40.430204  -3.698828       227
# 4              2    9.0  40.440927  -3.717716       133
#
#                                 property_description  \
# 0  Fantástico tríplex muy luminoso y bien ubicado...
# 1  Este exclusivo inmueble, ubicado en el prestig...
# 2  Presentamos una espectacular vivienda de lujo,...
# 3  Vivienda totalmente reformada y amueblada que ...
# 4  DIZA Consultores presenta atico triplex en el ...
#
#                                      property_images  ...  clip_embedding_502  \
# 0  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...            0.088012
# 1  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...            0.177028
# 2  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...            0.176593
# 3  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...            0.264297
# 4  ['https://img4.idealista.com/blur/WEB_DETAIL-X...  ...            0.064518
#
#   clip_embedding_503 clip_embedding_504  clip_embedding_505  \
# 0           0.033665           0.061926           -0.143020
# 1           0.020110          -0.050671           -0.340645
# 2           0.241413           0.530343           -0.468056
# 3           0.457102           0.327148            0.380688
# 4           0.146055           0.190543           -0.077115
#
#    clip_embedding_506  clip_embedding_507  clip_embedding_508  \
# 0           -0.415904            0.266450            0.128748
# 1           -0.484489            0.471462           -0.046645
# 2           -0.552180            0.174422           -0.074663
# 3           -0.442238            0.259107           -0.211369
# 4           -0.406454            0.429265           -0.100653
#
#    clip_embedding_509  clip_embedding_510  clip_embedding_511
# 0            0.344940            0.001526           -0.070597
# 1            0.394740           -0.348216           -0.321303
# 2           -0.069067            0.097788           -0.001139
# 3            0.198061           -0.407147           -0.025518
# 4            0.289183           -0.061458           -0.313833
#
# [5 rows x 534 columns]
